# %%
import gpu_tracking as gt

gt.LoG(
    r'/Users/amfaber/Documents/tracking_script/gpu-tracking/testing/storm_data/1&7 A647.tif - drift corrected.tif',
    2.2,
    3.5,
    n_radii = 10,
    log_spacing = False,
    overlap_threshold = 0,
    characterize = True,
    doughnut_correction = True,
    snr = 1.2,
    minmass_snr = 0.8,
    truncate_preprocessed = True,
    illumination_sigma = 30,
    adaptive_background = 3,
)
# Out:
#        frame           y           x      mass    r        Rg        raw  \
# 0          0  347.882416  157.965805  7.358501  3.5  1.539195  52.276337
# 1          0  419.894958  269.807556  5.975134  3.5  1.633367  50.886959
# 2          0  503.123810  355.140411  5.567916  3.5  1.483132  45.815239
# 3          0  273.815918  204.935867  4.897342  3.5  1.515049  45.486790
# 4          0  138.736618  221.255508  4.811922  3.5  1.557980  46.347153
# ...      ...         ...         ...       ...  ...       ...        ...
# 26851    380  152.019424  416.106934  3.068334  2.2  1.242425  23.230198
# 26852    380  352.156128  490.925323  3.024050  2.2  1.286429  24.875172
# 26853    380  257.062866  426.077057  3.001159  2.2  1.330191  28.479792
# 26854    380  283.973267  498.717285  2.998563  2.2  1.371609  14.307200
# 26855    380  476.853455  107.691841  2.972066  2.2  1.276801  19.337301
#
#          signal  ecc  raw_mass  raw_bg_median  raw_mass_corrected
# ...
